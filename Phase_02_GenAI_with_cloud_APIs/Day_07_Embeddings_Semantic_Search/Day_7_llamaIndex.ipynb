# %%
# !pip install llama-index llama-index-llms-groq sentence-transformers --q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 97.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 60.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 67.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 32.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.9/394.9 kB 24.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.2/121.2 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.9/343.9 kB 23.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 50.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.4/142.4 kB 11.5 MB/s eta 0:00:00
# ...

# %%
# !pip install llama-index-embeddings-huggingface --q

# %%
import os
from textwrap import dedent   #if we write python file it downaod .txt file

os.makedirs("data",exist_ok=True)

file_path="data/Data.txt"

content=dedent("""
ALLIMUTHU S
Phone : 8056623223| Email : allimuthu.s2024aids@sece.ac.in|Linkedin
CERTIFICATIONS
Introduction to C | Sololearn
Completion of C++ Training | IIT Bombay
Mastering Data Structures and Algorithms using C and C++ | Udemy
Mastering Agentic AI | Great Learning
GenerativeAIPoweredapps | GreatLearning
EDUCATION
B.tech(AI&DS) - Sri Eshwar College of Engineering || CGPA:8.2
HSC – Our Lady of Lourdes Matric Higher Secondary School ||92%
SSLC – Our Lady of Lourdes Matric Higher Secondary School || 90%
CODING PROFILES
Leetcode : Solved 120+problems  link
Skill Rack : Solved 1000+ problems | Received 5 certificates | 139Bronzes link
SKILLS
Programming - C | C++(learning) | Python(learning) |Java(learning)
Core Concepts – Data Structures |DBMS
Web Technologies - HTML | CSS | JavaScript
Tools - VSCode | Canva | Excel | PowerPoint | Jupyter Notebook | GitHub | Git | Replit | Codeblocks |
PowerBI
2024
2024
2025
2025
2025
2024-2028
2023-2024
2022-2023
PROJECTS
HealthSense – AI-Powered Disease Prediction:
Developed an interactive web application using Python and Streamlit that predicts possible diseases
based on user-input symptoms. The system leverages machine learning (Random Forest Classifier)
trained on symptom–disease datasets to provide accurate predictions. It also suggests preventive
precautions for the predicted disease. Implemented data preprocessing, feature encoding, and model
training using Pandas, NumPy, and Scikit-learn, ensuring real-time prediction and user-friendly
visualization..
Food Pre-Order System:
2025
2025
A simple and efficient platform for pre-ordering meals from restaurants or canteens. Users can browse menus, schedule pickup
times, and avoid long queues.It streamlines the food ordering process with digital payments and real-time order tracking.
The platform also provides order history, notifications, and customized meal recommendations based on user preferences.
Restaurants can manage inventory, analyze sales trends, and handle peak-hour demands efficiently.
Ideal for college campuses, offices, and small food outlets aiming to enhance convenience, reduce wait times, and improve
customer satisfaction.s.
Medicine Inventory and Delivery Management System:
Medicine Inventory and Delivery Management System – Developed a Java-based application
with a MySQL backend that allows users to order medicines online while enabling pharmacists to
track orders, manage stock levels, and monitor delivery status. Implemented secure authentication,
role-based access, and RESTful APIs for efficient data handling. The system ensures real-time
inventory updates and smooth coordination between customers, pharmacists, and delivery personnel..
2025
""").strip()

with open(file_path,"w",encoding="utf-8") as f:
  f.write(content)
print("Created file")
# Out:
# Created file

# %%
import os
from llama_index.llms.groq import Groq
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

os.environ["GROQ_API_KEY"] = ""
llm = Groq(model="llama-3.1-8b-instant")

embed_model = HuggingFaceEmbedding(model_name="sentence-transformers/all-MiniLM-L6-v2")

file_path = "data/Data.txt"
documents = SimpleDirectoryReader(input_files=[file_path]).load_data()

index = VectorStoreIndex.from_documents(documents, embed_model=embed_model)

query_engine = index.as_query_engine(llm=llm)

response = query_engine.query("whether this person it placced or not")
print("\n Document SUmmary : ",response)
# Out:
#  Document SUmmary :  It appears that this individual has had a successful career and has gained valuable experience in the field of Artificial Intelligence and Data Science. They have completed various certifications, projects, and have a strong educational background.
