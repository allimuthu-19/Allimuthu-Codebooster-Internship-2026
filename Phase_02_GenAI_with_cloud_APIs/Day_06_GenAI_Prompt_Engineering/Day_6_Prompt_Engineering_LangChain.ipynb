# %%
# !pip install langchain langchain-groq langchain-community langchain-core --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 20.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 22.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 2.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.

# %%
import os
from langchain_groq import ChatGroq
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

os.environ["GROQ_API_KEY"] = ""

llm = ChatGroq(model="llama-3.3-70b-versatile",temperature=0)

prompt = PromptTemplate(
    input_variables = ["instruction"],
    template="Follow the instruction and provide the output cleary:\n\nInstruction:{instruction}"
)
parser = StrOutputParser()
chain = prompt | llm | parser
response = chain.invoke({
    "instruction":"give me the detailed imformation about the Sri eshwar college of engineering in coimbatore"
}
)
print(response)
# Out:
# **Sri Eshwar College of Engineering, Coimbatore: Detailed Information**
#
# ### Overview
#
# Sri Eshwar College of Engineering (SECE) is a private engineering college located in Coimbatore, Tamil Nadu, India. The college was established in 2008 by the Sri Eshwar Charitable Trust. SECE is affiliated with Anna University, Chennai, and is approved by the All India Council for Technical Education (AICTE), New Delhi.
#
# ### Academic Programs
#
# Sri Eshwar College of Engineering offers undergraduate and postgraduate programs in various fields of engineering and technology. The college provides the following courses:
#
# * **Undergraduate Programs (B.E./B.Tech.)**:
# 	+ Computer Science and Engineering
# 	+ Electronics and Communication Engineering
# 	+ Electrical and Electronics Engineering
# 	+ Mechanical Engineering
# 	+ Civil Engineering
# 	+ Information Technology
# * **Postgraduate Programs (M.E./M.Tech.)**:
# 	+ Computer Science and Engineering
# 	+ VLSI Design
# 	+ Embedded Systems
# 	+ Power Electronics and Drives
# 	+ Structural Engineering
# 	+ Construction Engineering and Management
# * **Master of Business Administration (MBA)**: The college also offers a two-year MBA program with specializations in Marketing, Finance, Human Resources, and Operations Management.
# * **Master of Computer Applications (MCA)**: A three-year MCA program is also offered by the college.
#
# ### Infrastructure and Facilities
#
# Sri Eshwar College of Engineering has a sprawling campus with modern infrastructure and facilities, including:
#
# * **Classrooms**: Well-equipped classrooms with audio-visual aids and internet connectivity.
# * **Laboratories**: State-of-the-art laboratories for various departments, including computer science, electronics, electrical, mechanical, and civil engineering.
# * **Library**: A well-stocked library with a collection of over 20,000 books, journals, and online resources.
# * **Sports and Games**: Facilities for indoor and outdoor games, including cricket, football, basketball, volleyball, and table tennis.
# * **Hostel**: Separate hostels for boys and girls, with modern amenities and 24/7 security.
# * **Canteen**: A hygienic canteen serving a variety of food and beverages.
# * **Transportation**: The college provides bus transportation for students and staff from various parts of Coimbatore.
#
# ### Research and Development
#
# Sri Eshwar College of Engineering has a strong focus on research and development, with various research centers and cells, including:
#
# * **Research and Development Cell**: Encourages faculty and students to undertake research projects and publish papers in national and international journals.
# * **Innovation and Entrepreneurship Cell**: Fosters innovation and entrepreneurship among students, with support for start-ups and incubation.
# * **Industry-Institute Partnership Cell**: Collaborates with industries to provide training, projects, and placement opportunities for students.
#
# ### Placement and Training
#
# The college has a dedicated placement and training cell, which provides:
#
# * **Placement**: Assistance for students to get placed in top companies, with a strong track record of placement.
# * **Training**: Soft skills training, technical training, and personality development programs to prepare students for the industry.
# * **Internships**: Opportunities for students to undergo internships in industries and research organizations.
#
# ### Admission Procedure
#
# Admission to Sri Eshwar College of Engineering is based on the following criteria:
#
# * **Undergraduate Programs**: Admission is based on the Tamil Nadu Engineering Admission (TNEA) counseling, with eligibility criteria as per Anna University norms.
# * **Postgraduate Programs**: Admission is based on the Tamil Nadu Common Entrance Test (TANCET) or Graduate Aptitude Test in Engineering (GATE) scores, with eligibility criteria as per Anna University norms.
# * **MBA and MCA Programs**: Admission is based on the Tamil Nadu Common Entrance Test (TANCET) or other national-level entrance exams, with eligibility criteria as per Anna University norms.
#
# ### Contact Information
#
# Sri Eshwar College of Engineering,
# Kondampatti,
# Coimbatore - 641 202,
# Tamil Nadu, India.
# Phone: +91 422 2681111
# Email: [info@sece.ac.in](mailto:info@sece.ac.in)
# Website: [www.sece.ac.in](http://www.sece.ac.in)
#
# Note: The information provided is subject to change, and it is recommended to visit the college website or contact the college directly for the latest information.

# %%
from twilio.rest import Client

prompt=PromptTemplate(
    input_variables=["instruction"],
    template="Read the Instruction and give the output clealry:{instruction}"

)
parser=StrOutputParser()
chain=prompt |llm|parser

response=chain.invoke({
    "instruction":"You are Leetcode Solver Give a Problem Solution in Python for 'Two Sum'"
})


FROM='whatsapp:+14155238886.'

TO='whatsapp:+918056623223'

# Define TW_SID and TW_TOKEN here or as environment variables
# Example:
# TW_SID = 'ACxxxxxxxxxxxxxxxxxxxxxxxxxxxxx'
# TW_TOKEN = 'your_auth_token'

client=Client(TW_SID,TW_TOKEN)

# Truncate the response to fit within Twilio's 1600 character limit
truncated_response = response[:1600] if len(response) > 1600 else response

msg=client.messages.create(
    body=truncated_response,
    from_=FROM,
    to=TO
)

print('Message sent successfully')
print('Message SID:',msg.sid)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_10808/1077571196.py in <cell line: 0>()
# ----> 1 from twilio.rest import Client
#       2
#       3 prompt=PromptTemplate(
#       4     input_variables=["instruction"],
#       5     template="Read the Instruction and give the output clealry:{instruction}"
#
# ModuleNotFoundError: No module named 'twilio'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
